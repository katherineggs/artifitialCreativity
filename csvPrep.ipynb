# %%
import pandas as pd
import os

# %%
file = pd.read_csv("archive/csv/DuaLipa.csv")

# %%
file = file.drop(["Artist", "Title", "Album", "Date", "Year"], axis=1) # intentar no botar todas

# %%
file.head()
# Out:
#      Unnamed: 0    Artist                                              Title  \
# 0             0  Dua Lipa                                          New Rules
# 1             1  Dua Lipa                                    Don’t Start Now
# 2             2  Dua Lipa                                              IDGAF
# 3             3  Dua Lipa                              Blow Your Mind (Mwah)
# 4             4  Dua Lipa                                         Be the One
# ..          ...       ...                                                ...
# 242         242  Dua Lipa             Hotter Than Hell (Carsten Fietz Remix)
# 243         243  Dua Lipa               Future Nostalgia (Jon Goddard Remix)
# 244         244  Dua Lipa  Dua Lipa - Blow Your Mind (Mwah) (Traducción a...
# 245         245  Dua Lipa  Dua Lipa - Hotter Than Hell (Traducción al Esp...
# 246         246  Dua Lipa           Dua Lipa - IDGAF (Traducción al Español)
#
#                                                  Album    Year        Date  \
# 0                                             Dua Lipa  2017.0  2017-06-02
# 1                                     Future Nostalgia  2019.0  2019-11-01
# 2                                             Dua Lipa  2017.0  2017-06-02
# 3                                             Dua Lipa  2016.0  2016-08-26
# 4                                             Dua Lipa  2015.0  2015-10-30
# ..                                                 ...     ...         ...
# 242                         Hotter Than Hell (Remixes)     NaN         NaN
# 243                                                NaN     NaN         NaN
# 244  Dua Lipa: Complete Edition - Dua Lipa (Traducc...  2016.0  2016-08-26
# 245  Dua Lipa: Complete Edition - Dua Lipa (Traducc...  2016.0  2016-05-06
# 246  Dua Lipa: Complete Edition - Dua Lipa (Traducc...  2017.0  2017-06-02
#
#                                                  Lyric
# 0    one one one one one   talkin' in my sleep at n...
# 1    if you don't wanna see me   did a full 80 craz...
# 2    you call me all friendly tellin' me how much y...
# 3    i know it's hot i know we've got something tha...
# 4    i see the moon i see the moon i see the moon o...
# ..                                                 ...
# 242  ah yeah ah yeah   he calls me the devil i make...
# 243  lyrics for this song have yet to be released p...
# 244  verso  se que hace calor sé que tenemos algo q...
# 245  ah yeah ah yeah  verso  el me llama el diablo ...
# 246  verso  me llamas todo amigable dime cuanto me ...
#
# [247 rows x 7 columns]

# %%
specialChars = "!@#$%^&*()-+?_=,<>/Œ€"

# specialChars = ["!", "@", "#", "$", "%", "^", "&", "*", "(", ")", "-", "+", "?", "_", "=", "<", ">", "Œ", "€", "/"]
for lyrics in file["Lyric"]:
    # if any(specialChars in word for word in lyrics):
    if any(spec in lyrics for spec in specialChars):
        print("yes")

# %%
lyrics = "The world is am@zing"
if any( lyrics.replace(spec, "") for spec in specialChars if spec in str(lyrics) ):
    print("YES")
    print(lyrics)
# Out:
# YES
# The world is am@zing

# %%
specialChars = ["!", "@", "#", "$", "%", "^", "&", "*", "(", ")", "-", "+", "?", "_", "=", "<", ">", "Œ", "€", "/"]
notLyrics = ["unreleased", "lyrics for this song have not yet been released please come back once they have been released",
"lyrics for this song have yet to be released please check back once the song has been released", "lyrics from snippet",
"lyrics will be available upon release stay tuned", "tba", "ariii  kim", "released in 09", "snippet", "come back soon when there is lyrics",
"no lyrics for this song come back soon"]
artists = []
lyrics = []
def readAllCSVs(folderP):
    result = []
    for filename in os.listdir(folderP):
        file = pd.read_csv(folderP+filename)
        file = file.drop(["Artist", "Title", "Album", "Date", "Year"], axis=1) # intentar no botar todas
        # artists.append(filename.replace(".csv",""))
        for eachLyric in file["Lyric"]:
            for spec in specialChars:
                if spec in str(eachLyric):
                    eachLyric = eachLyric.replace(spec, "")
                    # print("yes")
            for noL in notLyrics:
                if str(eachLyric).startswith(noL):
                    print("x")
                    break

            artists.append(filename.replace(".csv",""))
            lyrics.append(eachLyric)
    
    df = pd.DataFrame(
    {'Artist': artists,
     'Lyrics': lyrics
    })
    
    return df

# %%
x = readAllCSVs("archive/csv/")
x[230:255]
# Out:
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
#            Artist                                             Lyrics
# 230       DuaLipa  one one one one one   talkin' in my sleep at n...
# 231       DuaLipa  lyrics for this song haven't released check ba...
# 232       DuaLipa  i know it's hot i know we've got something tha...
# 233       DuaLipa  ah yeah ah yeah   he calls me the devil i make...
# 234       DuaLipa  fatal this attraction yeah we might just end u...
# 235       DuaLipa  i know it's hot i know we've got something tha...
# 236       DuaLipa  fox if you don't wanna see me   did a full 80 ...
# 237       DuaLipa  now it's getting quiet here now it's getting b...
# 238       DuaLipa  dua lipa falling into you baby even electricit...
# 239       DuaLipa  hey hey   after a few drains i started to thin...
# 240       DuaLipa  now it's getting quiet here now it's getting b...
# 241       DuaLipa  ah yeah ah yeah   he calls me the devil i make...
# 242       DuaLipa  ah yeah ah yeah   he calls me the devil i make...
# 243       DuaLipa  lyrics for this song have yet to be released p...
# 244       DuaLipa  verso  se que hace calor sé que tenemos algo q...
# 245       DuaLipa  ah yeah ah yeah  verso  el me llama el diablo ...
# 246       DuaLipa  verso  me llamas todo amigable dime cuanto me ...
# 247  ArianaGrande  thought i'd end up with sean but he wasn't a m...
# 248  ArianaGrande  yeah breakfast at tiffany's and bottles of bub...
# 249  ArianaGrande  you you love it how i move you you love it how...
# 250  ArianaGrande  ariana grande  nicki minaj i've been here all ...
# 251  ArianaGrande  right now i'm in a state of mind i wanna be in...
# 252  ArianaGrande  lacigam gnihtemos od ot thgin laiceps ruoy s't...
# 253  ArianaGrande  you got me some type of way hmm ain't used to ...
# 254  ArianaGrande  heaven sent you to me i'm just hopin i don't r...
